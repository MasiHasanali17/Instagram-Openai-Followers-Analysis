# %% [markdown]
# # Project Description:
#
# In this project, we collect raw Instagram data for all OpenAI followers and analyze it to answer the following questions:
#
# -->Who has the highest number of posts?
#
# -->Who has the max followers?
#
# -->Who follows maximum people?
#
# -->How many profile categories exist (e.g., Digital Creator, Non-profit Foundation), and how many users fall into each category?

# %%
with open("finaldata.txt" , encoding='utf-8') as f:
    data = f.read()

# %%
chunks = data.split("\n\n")

# %%
chunks = data.split("\n\n") 
chunks = [c for c in chunks if len(c)>3]
chunks
# Out:
# ['techie_koramangala\n420 posts\n9,800 followers\n310 following\nArjun M.\nSoftware Engineer\n💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes',
#  'blrcoder_girl\n150 posts\n6,300 followers\n120 following\nRiya Codes\nTech Creator\n👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes',
#  'hsr_startup_stories\n980 posts\n22.4K followers\n95 following\nStartup Stories HSR\nMedia\n🚀 Interviews with Bangalore founders\n🎙️ Weekly startup breakdowns\nhsrstartupstories.com',
#  'cloud_dev_blr\n210 posts\n4,500 followers\n60 following\nNaveen DevOps\nEngineer\n☁️ AWS | Docker | K8s\n📍 Sarjapur\ngithub.com/naveencloud',
#  'koramangala_coffee_lover\n300 posts\n7,900 followers\n180 following\nSana B.\nCafe Explorer\n☕ Reviewing Bangalore’s hidden coffee spots\n📍 Koramangala\nyoutube.com/@sanacafehunter',
# ...

# %%
def parse_chunk(chunk): 
        chunk = chunk.strip()
        sep_chunk = chunk.split('\n')
        username = sep_chunk[0]
    
        no_of_posts = int(sep_chunk[1].split(" post")[0].replace(",", ""))
        no_of_followers = float(sep_chunk[2].split(" follower")[0].replace(",", "").replace("K", "").replace("M", ""))
        if("K" in sep_chunk[2]):
            no_of_followers = int(no_of_followers * 1000)
        elif("M" in sep_chunk[2]):
            no_of_followers = int(no_of_followers * 1000000)
        else:
            no_of_followers = int(no_of_followers)

        no_of_following = float(sep_chunk[3].split(" following")[0].replace(",", "").replace("K", "").replace("M", ""))

    
        if("K" in sep_chunk[3]):
            no_of_following = int(no_of_following * 1000)
        elif("M" in sep_chunk[3]):
            no_of_following = int(no_of_following * 1000000)
        else:
            no_of_following = int(no_of_following)

    
        name = sep_chunk[4]
        if(len(sep_chunk)> 5):
            type_of_page = sep_chunk[5]
            bio = "\n".join(sep_chunk[6:])
        else:
            type_of_page = "Unknown"
            bio = ""
        
        return {"username": username, "no_of_posts": no_of_posts, "no_of_followers": no_of_followers,"type_of_page": type_of_page, 
                "no_of_following": no_of_following, "name": name, "type_of_page": type_of_page, "bio": bio}

# %%
all_chunks = [] 
for chunk in chunks:  
    parsed_chunk = parse_chunk(chunk)
    all_chunks.append(parsed_chunk)
print(all_chunks)
# Out:
# [{'username': 'techie_koramangala', 'no_of_posts': 420, 'no_of_followers': 9800, 'type_of_page': 'Software Engineer', 'no_of_following': 310, 'name': 'Arjun M.', 'bio': '💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes'}, {'username': 'blrcoder_girl', 'no_of_posts': 150, 'no_of_followers': 6300, 'type_of_page': 'Tech Creator', 'no_of_following': 120, 'name': 'Riya Codes', 'bio': '👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes'}, {'username': 'hsr_startup_stories', 'no_of_posts': 980, 'no_of_followers': 22400, 'type_of_page': 'Media', 'no_of_following': 95, 'name': 'Startup Stories HSR', 'bio': '🚀 Interviews with Bangalore founders\n🎙️ Weekly startup breakdowns\nhsrstartupstories.com'}, {'username': 'cloud_dev_blr', 'no_of_posts': 210, 'no_of_followers': 4500, 'type_of_page': 'Engineer', 'no_of_following': 60, 'name': 'Naveen DevOps', 'bio': '☁️ AWS | Docker | K8s\n📍 Sarjapur\ngithub.com/naveencloud'}, {'u
# ...

# %%
import json
s = json.dumps(all_chunks, indent=4)
print(s)
# Out:
# [
#     {
#         "username": "techie_koramangala",
#         "no_of_posts": 420,
#         "no_of_followers": 9800,
#         "type_of_page": "Software Engineer",
#         "no_of_following": 310,
#         "name": "Arjun M.",
#         "bio": "\ud83d\udcbb Full-stack @ SaaS startup\n\u2615 Working from cafes in Koramangala\ngithub.com/arjunmakes"
#     },
#     {
#         "username": "blrcoder_girl",
#         "no_of_posts": 150,
#         "no_of_followers": 6300,
#         "type_of_page": "Tech Creator",
#         "no_of_following": 120,
#         "name": "Riya Codes",
#         "bio": "\ud83d\udc69\u200d\ud83d\udcbb Python | ML | Roadmaps\n\ud83c\udfa5 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes"
#     },
#     {
#         "username": "hsr_startup_stories",
#         "no_of_posts": 980,
#         "no_of_followers": 22400,
#         "type_of_page": "Media",
#         "no_of_following": 95,
#         "name": "Startup Stories HSR",
# ...

# %% [markdown]
# # Who has the highest number of posts?
#     code to write max posts

# %%
max = 0
for chunk in all_chunks:
    if(max < chunk['no_of_posts']):
        max = chunk['no_of_posts']
        chunk_with_max_post = chunk

print(chunk_with_max_post['username'])
# Out:
# startuphub_blr

# %% [raw]
# ANS : startuphub_blr has maximum post (2300)

# %% [markdown]
# # Who has the max followers?
#     code to write max followers

# %%
max = 0
for chunk in all_chunks:
    if(max < chunk['no_of_followers']):
        max = chunk['no_of_followers']
        chunk_with_max_followers = chunk

print(chunk_with_max_followers['username'])
# Out:
# _anujsinghal

# %% [raw]
# ANS : _anujsinghal

# %% [markdown]
# # Who follows maximum people
#     code to find who follow maximum people

# %%
max = 0
for chunk in all_chunks:
    if(max < chunk['no_of_following']):
        max = chunk['no_of_following']
        chunk_with_max_following = chunk

print(chunk_with_max_following['username'])
# Out:
# bangalore_tech_bro

# %% [raw]
# ANS : bangalore_tech_bro

# %% [markdown]
# # How many Categories?
#     code to find How many Categories

# %%
categories = set()
for chunk in all_chunks:
    categories.add(chunk['type_of_page'])
print(len(categories))
# Out:
# 34

# %% [raw]
# ANS : 34
